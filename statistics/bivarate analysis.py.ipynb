# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/nates/Downloads/BivariateData.csv")
df
# Out:
#     Hours_Studied  Test_Score  Stress_Level  Shoe_Size
# 0             1.0          55           8.0          9
# 1             1.0          58           7.5         11
# 2             3.0          62           7.0          8
# 3             3.0          68           6.5         10
# 4             4.0          72           6.0          9
# 5             4.0          75           5.5         12
# 6             5.0          80           5.0          7
# 7             5.0          85           4.5         10
# 8             5.0          88           4.0         11
# 9             6.0          90           3.5          8
# 10            6.0          92           3.0          9
# 11            6.0          95           2.5         10
# 12            6.5          96           2.0         11
# 13            6.5          97           1.5          8
# 14            6.5          98           1.0          9

# %%
df['Hours_Studied'].cov(df['Test_Score'])
# Out:
# np.float64(27.090476190476195)

# %%
df['Test_Score'].cov(df['Stress_Level'])
# Out:
# np.float64(-32.535714285714285)

# %%
df['Test_Score'].cov(df['Shoe_Size'])
# Out:
# np.float64(-1.2238095238095237)

# %% [markdown]
# corralation

# %%
df['Hours_Studied'].corr(df['Test_Score'])
# Out:
# np.float64(0.9761563475950298)

# %%
df['Test_Score'].corr(df['Stress_Level'])
# Out:
# np.float64(-0.9802039983413031)

# %%
df['Test_Score'].corr(df['Shoe_Size'])
# Out:
# np.float64(-0.05857576064343221)

# %%
from matplotlib import pyplot as plt

plt.scatter(df['Hours_Studied'],df['Test_Score'])

# %%
plt.scatter(df['Test_Score'],df['Shoe_Size'])

# %%
df.corr()
# Out:
#                Hours_Studied  Test_Score  Stress_Level  Shoe_Size
# Hours_Studied       1.000000    0.976156     -0.948291  -0.175540
# Test_Score          0.976156    1.000000     -0.980204  -0.058576
# Stress_Level       -0.948291   -0.980204      1.000000   0.079436
# Shoe_Size          -0.175540   -0.058576      0.079436   1.000000

# %%
import seaborn as sns

plt.figure(figsize=(8, 6)) # Adjust figure size as needed
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.pairplot(df)
